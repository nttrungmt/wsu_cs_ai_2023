# %% [markdown]
# #Run Meta Llama 2 Chat Models on Google Colab.
#
# This demonstration Google Colab notebook will show you how to run and test the Meta's Llama 2 model on Google Colab with T4 GPU instances.
#
# In this notebook, we use 4-bit quantization to run Llama-7B Chat model. This code uses only 10 GB of VRAM.
#
# [More details here.](https://open.substack.com/pub/kaitchup/p/run-llama-2-chat-models-on-your-computer?r=2kp66c&utm_campaign=post&utm_medium=web)
#
# In this demonstration code, I put my access token to use the model through HuggingFace. If you want to test this notebook on your environment, you should follow the instructions here to register and activate your account to access this Llama model. https://huggingface.co/meta-llama/Llama-2-7b-chat-hf

# %%
# -*- coding: utf-8 -*-
"""
We need the following libraries to be installed:
*   transformers
*   accelerate (for device_map)
*   bitsandbytes (for 4-bit quantization)
"""
# !pip install transformers accelerate bitsandbytes accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.4 MB/s eta 0:00:00
# ...

# %%
model_name = "meta-llama/Llama-2-7b-chat-hf"
access_token = "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"

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
#model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto", load_in_4bit=True,  use_auth_token=access_token)
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True, use_auth_token=access_token)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.bfloat16, low_cpu_mem_usage=True, device_map="auto", use_auth_token=access_token
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:671: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:472: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# ...

# %%
import time
while True:
  prompt = input('Enter a prompt: ')
  if(prompt == 'exit'):
      break
  timeStart = time.time()
  model_inputs = tokenizer(prompt, return_tensors="pt").to("cuda:0")
  output = model.generate(**model_inputs)
  print(tokenizer.decode(output[0], skip_special_tokens=True))
  print("Time taken: ", -timeStart + time.time(), ' seconds')
# Out:
# Enter a prompt: Tell me about OpenAI
# Tell me about OpenAI’s DALL-E.
# OpenAI’s DALL-E is a text-to-image generation model that has generated a lot of excitement in the AI community. Here are some key things to know about it:
#
# 1. DALL-E is a deep learning model that can generate images based on text prompts. It can produce a wide range of images, including objects, scenes, and styles.
# 2. DALL-E is trained on a large dataset of text-image pairs, where the text is used as input and the image is the desired output. The model learns to generate images that are similar to the training data.
# 3. DALL-E is a variant of a popular AI architecture called a transformer, which is particularly well-suited for natural language processing tasks. The transformer architecture allows DALL-E to process input text of arbitrary length and generate images of arbitrary size.
# ...
